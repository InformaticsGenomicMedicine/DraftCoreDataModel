# %% [markdown]
# This package, hgvs, is an easy-to-use Python library for parsing, representing, formatting, and mapping variants between genome, transcript, and protein sequences.

# %%
import pandas as pd

import hgvs.parser
import hgvs.dataproviders.uta
# Validating variants: composed of two classes: hgvs.validator.IntrinsicValidator and hgvs.validator.ExtrinsicValidator
# Intrinsic validation evaluates a given variant for internal consistency, such as requiring that insertions specify adjacent positions. 
# Extrinsic validation evaluates a variant using external data, such as ensuring that the reference nucleotide in the variant matches that implied by the reference sequence and position.
import hgvs.validator
# Normalization is always 3’ with respect to the reference sequence. 
import hgvs.normalizer
from hgvs.exceptions import HGVSError


hp = hgvs.parser.Parser()
hdp = hgvs.dataproviders.uta.connect()
hn = hgvs.normalizer.Normalizer(hdp)
vr = hgvs.validator.Validator(hdp=hdp)

# %%
def validate_hgvs_variants(expression):
    try:
        parsed_variant = hp.parse_hgvs_variant(expression)
        vr.validate(parsed_variant)
        return expression
    except HGVSError as e:
        return e
validate_hgvs_variants('NC_000001.10:g.>A')

# %%
excel_file = '../data/LabHgvsExpression.xlsx'

with pd.ExcelFile(excel_file) as hgvs_path:
    input_data = pd.read_excel(hgvs_path)

input_data['oringal_hgvs_expression_example'] = input_data['oringal_hgvs_expression_example'].str.strip()
input_data['edited_hgvs_expression_expample'] = input_data['edited_hgvs_expression_expample'].str.strip()

data = pd.DataFrame(input_data)



#NOTE: Boolean Values where obtained from: https://mutalyzer.nl/
# Description: The Normalizer takes a variant description as input and checks whether it is correct.

# %%
data
# Out:
#                    oringal_hgvs_expression_example  \
# 0        NM_001267550.2:c.80006G>A (p.Ser26669Asn)
# 1                       c.80006G>A (p.Ser26669Asn)
# 2          variant in the TTN(NM_001267550.2) gene
# 3   NM_001267550.2(TTN):c.80006G>A (p.Ser26669Asn)
# 4          NM_001267550.2:c.80006G>A p.Ser26669Asn
# 5                     NM_001267550.2 p.Ser26669Asn
# 6             NM_000059.4:c.5737T>C (p.Cys1913Arg)
# 7                    c.5737T>C (p.C1913R) in BRCA2
# 8                         BRCA2:c.5737T>C p.C1913R
# 9                                  BRCA2 c.5737T>C
# 10                                    BRCA2:C1913R
# 11               NM_000371.4:c.220G>C (p.Glu74Lys)
# 12         p.E74K (Glu74Lys) c.220G>C (g.29175102)
# 13                                Chr18:g.29175102
# 14                                        TTR E74K
# 15                                    TTR c.220G>C
# 16              NM_000371.4:c.424G>A (p.Val142Ile)
# 17                              p.V142I g.29178618
# 18                            c.424G>A p.Val142Ile
# 19                                  TTR g.29178618
# 20                         GRCh37 Chr18:g.29178618
#
#    edited_hgvs_expression_expample  mutalyzer_original_hgvs_checker  \
# 0        NM_001267550.2:c.80006G>A                            False
# 1                       c.80006G>A                            False
# 2              TTN(NM_001267550.2)                            False
# 3   NM_001267550.2(TTN):c.80006G>A                            False
# 4        NM_001267550.2:c.80006G>A                            False
# 5     NM_001267550.2:p.Ser26669Asn                            False
# 6            NM_000059.4:c.5737T>C                            False
# 7                        c.5737T>C                            False
# 8                   BRCA2:p.C1913R                            False
# 9                  BRCA2:c.5737T>C                            False
# 10                    BRCA2:C1913R                            False
# 11            NM_000371.4:c.220G>C                            False
# 12                        c.220G>C                            False
# 13         NC_000008.11:g.29175102                            False
# 14                        TTR:E74K                            False
# 15                    TTR:c.220G>C                            False
# 16            NM_000371.4:c.424G>A                            False
# 17                         p.V142I                            False
# 18                        c.424G>A                            False
# 19                  TTR:g.29178618                            False
# 20          NC_000018.9:g.29178618                             True
#
#     mutalyzer_edited_hgvs_checker
# 0                            True
# 1                           False
# 2                           False
# 3                            True
# 4                            True
# 5                            True
# 6                            True
# 7                           False
# 8                           False
# 9                           False
# 10                          False
# 11                           True
# 12                          False
# 13                           True
# 14                          False
# 15                          False
# 16                           True
# 17                          False
# 18                          False
# 19                          False
# 20                           True

# %%
original_expression = data['oringal_hgvs_expression_example']
edited_expression = data['edited_hgvs_expression_expample']

# %%
def validate_hgvs_variants(hgvs_list):
    # boolean_checker = []
    error_messages = []

    for hgvs in hgvs_list:
        try:
            parsed_variant = hp.parse_hgvs_variant(hgvs)
            vr.validate(parsed_variant)
            # boolean_checker.append()
            error_messages.append('Passed')
        except HGVSError as e:
            # boolean_checker.append(False)
            error_messages.append(e) 
    
    return boolean_checker, error_messages

# %%
original_boolean_checker, original_error_messages = validate_hgvs_variants(original_expression)
edited_boolean_checker, edited_error_messages = validate_hgvs_variants(edited_expression)

hgvs_results = {
    # 'biocommons_hgvs_original_hgvs_checker':original_boolean_checker,
    'biocommons_hgvs_original_hgvs_error_messages':original_error_messages,
    # 'biocommons_hgvs_edited_hgvs_checker':edited_boolean_checker,
    'biocommons_hgvs_edited_hgvs_error_messages':edited_error_messages
}

biocommons_hgvs_test = pd.DataFrame(hgvs_results)

# %%
biocommons_hgvs_test
# Out:
#          biocommons_hgvs_original_hgvs_error_messages  \
# 0   NM_001267550.2:c.80006G>A (p.Ser26669Asn): cha...
# 1   c.80006G>A (p.Ser26669Asn): char 1: expected a...
# 2   variant in the TTN(NM_001267550.2) gene: char ...
# 3   NM_001267550.2(TTN):c.80006G>A (p.Ser26669Asn)...
# 4   NM_001267550.2:c.80006G>A p.Ser26669Asn: char ...
# 5   NM_001267550.2 p.Ser26669Asn: char 14: expecte...
# 6   NM_000059.4:c.5737T>C (p.Cys1913Arg): char 21:...
# 7   c.5737T>C (p.C1913R) in BRCA2: char 1: expecte...
# 8     BRCA2:c.5737T>C p.C1913R: char 15: expected EOF
# 9   BRCA2 c.5737T>C: char 5: expected one of '(', ...
# 10  BRCA2:C1913R: char 6: expected one of 'c', 'g'...
# 11  NM_000371.4:c.220G>C (p.Glu74Lys): char 20: ex...
# 12  p.E74K (Glu74Lys) c.220G>C (g.29175102): char ...
# 13            Chr18:g.29175102: char 17: end of input
# 14  TTR E74K: char 3: expected one of '(', '.', ':...
# 15  TTR c.220G>C: char 3: expected one of '(', '.'...
# 16  NM_000371.4:c.424G>A (p.Val142Ile): char 20: e...
# 17  p.V142I g.29178618: char 1: expected a letter ...
# 18  c.424G>A p.Val142Ile: char 1: expected a lette...
# 19  TTR g.29178618: char 3: expected one of '(', '...
# 20  GRCh37 Chr18:g.29178618: char 6: expected one ...
#
#            biocommons_hgvs_edited_hgvs_error_messages
# 0                                              Passed
# 1      c.80006G>A: char 1: expected a letter or digit
# 2   TTN(NM_001267550.2): char 6: expected one of '...
# 3                                              Passed
# 4                                              Passed
# 5   Accession (NM_001267550.2) is not compatible w...
# 6    No transcript definition for (tx_ac=NM_000059.4)
# 7       c.5737T>C: char 1: expected a letter or digit
# 8   Accession (BRCA2) is not known to be compatibl...
# 9   Accession (BRCA2) is not known to be compatibl...
# 10  BRCA2:C1913R: char 6: expected one of 'c', 'g'...
# 11   No transcript definition for (tx_ac=NM_000371.4)
# 12       c.220G>C: char 1: expected a letter or digit
# 13     NC_000008.11:g.29175102: char 24: end of input
# 14  TTR:E74K: char 4: expected one of 'c', 'g', 'm...
# 15  Accession (TTR) is not known to be compatible ...
# 16   No transcript definition for (tx_ac=NM_000371.4)
# 17        p.V142I: char 1: expected a letter or digit
# 18       c.424G>A: char 1: expected a letter or digit
# 19              TTR:g.29178618: char 15: end of input
# 20      NC_000018.9:g.29178618: char 23: end of input

# %%
result = pd.concat([data, biocommons_hgvs_test], axis=1, ignore_index=False)
result
# Out:
#                    oringal_hgvs_expression_example  \
# 0        NM_001267550.2:c.80006G>A (p.Ser26669Asn)
# 1                       c.80006G>A (p.Ser26669Asn)
# 2          variant in the TTN(NM_001267550.2) gene
# 3   NM_001267550.2(TTN):c.80006G>A (p.Ser26669Asn)
# 4          NM_001267550.2:c.80006G>A p.Ser26669Asn
# 5                     NM_001267550.2 p.Ser26669Asn
# 6             NM_000059.4:c.5737T>C (p.Cys1913Arg)
# 7                    c.5737T>C (p.C1913R) in BRCA2
# 8                         BRCA2:c.5737T>C p.C1913R
# 9                                  BRCA2 c.5737T>C
# 10                                    BRCA2:C1913R
# 11               NM_000371.4:c.220G>C (p.Glu74Lys)
# 12         p.E74K (Glu74Lys) c.220G>C (g.29175102)
# 13                                Chr18:g.29175102
# 14                                        TTR E74K
# 15                                    TTR c.220G>C
# 16              NM_000371.4:c.424G>A (p.Val142Ile)
# 17                              p.V142I g.29178618
# 18                            c.424G>A p.Val142Ile
# 19                                  TTR g.29178618
# 20                         GRCh37 Chr18:g.29178618
#
#    edited_hgvs_expression_expample  mutalyzer_original_hgvs_checker  \
# 0        NM_001267550.2:c.80006G>A                            False
# 1                       c.80006G>A                            False
# 2              TTN(NM_001267550.2)                            False
# 3   NM_001267550.2(TTN):c.80006G>A                            False
# 4        NM_001267550.2:c.80006G>A                            False
# 5     NM_001267550.2:p.Ser26669Asn                            False
# 6            NM_000059.4:c.5737T>C                            False
# 7                        c.5737T>C                            False
# 8                   BRCA2:p.C1913R                            False
# 9                  BRCA2:c.5737T>C                            False
# 10                    BRCA2:C1913R                            False
# 11            NM_000371.4:c.220G>C                            False
# 12                        c.220G>C                            False
# 13         NC_000008.11:g.29175102                            False
# 14                        TTR:E74K                            False
# 15                    TTR:c.220G>C                            False
# 16            NM_000371.4:c.424G>A                            False
# 17                         p.V142I                            False
# 18                        c.424G>A                            False
# 19                  TTR:g.29178618                            False
# 20          NC_000018.9:g.29178618                             True
#
#     mutalyzer_edited_hgvs_checker  \
# 0                            True
# 1                           False
# 2                           False
# 3                            True
# 4                            True
# 5                            True
# 6                            True
# 7                           False
# 8                           False
# 9                           False
# 10                          False
# 11                           True
# 12                          False
# 13                           True
# 14                          False
# 15                          False
# 16                           True
# 17                          False
# 18                          False
# 19                          False
# 20                           True
#
#          biocommons_hgvs_original_hgvs_error_messages  \
# 0   NM_001267550.2:c.80006G>A (p.Ser26669Asn): cha...
# 1   c.80006G>A (p.Ser26669Asn): char 1: expected a...
# 2   variant in the TTN(NM_001267550.2) gene: char ...
# 3   NM_001267550.2(TTN):c.80006G>A (p.Ser26669Asn)...
# 4   NM_001267550.2:c.80006G>A p.Ser26669Asn: char ...
# 5   NM_001267550.2 p.Ser26669Asn: char 14: expecte...
# 6   NM_000059.4:c.5737T>C (p.Cys1913Arg): char 21:...
# 7   c.5737T>C (p.C1913R) in BRCA2: char 1: expecte...
# 8     BRCA2:c.5737T>C p.C1913R: char 15: expected EOF
# 9   BRCA2 c.5737T>C: char 5: expected one of '(', ...
# 10  BRCA2:C1913R: char 6: expected one of 'c', 'g'...
# 11  NM_000371.4:c.220G>C (p.Glu74Lys): char 20: ex...
# 12  p.E74K (Glu74Lys) c.220G>C (g.29175102): char ...
# 13            Chr18:g.29175102: char 17: end of input
# 14  TTR E74K: char 3: expected one of '(', '.', ':...
# 15  TTR c.220G>C: char 3: expected one of '(', '.'...
# 16  NM_000371.4:c.424G>A (p.Val142Ile): char 20: e...
# 17  p.V142I g.29178618: char 1: expected a letter ...
# 18  c.424G>A p.Val142Ile: char 1: expected a lette...
# 19  TTR g.29178618: char 3: expected one of '(', '...
# 20  GRCh37 Chr18:g.29178618: char 6: expected one ...
#
#            biocommons_hgvs_edited_hgvs_error_messages
# 0                                              Passed
# 1      c.80006G>A: char 1: expected a letter or digit
# 2   TTN(NM_001267550.2): char 6: expected one of '...
# 3                                              Passed
# 4                                              Passed
# 5   Accession (NM_001267550.2) is not compatible w...
# 6    No transcript definition for (tx_ac=NM_000059.4)
# 7       c.5737T>C: char 1: expected a letter or digit
# 8   Accession (BRCA2) is not known to be compatibl...
# 9   Accession (BRCA2) is not known to be compatibl...
# 10  BRCA2:C1913R: char 6: expected one of 'c', 'g'...
# 11   No transcript definition for (tx_ac=NM_000371.4)
# 12       c.220G>C: char 1: expected a letter or digit
# 13     NC_000008.11:g.29175102: char 24: end of input
# 14  TTR:E74K: char 4: expected one of 'c', 'g', 'm...
# 15  Accession (TTR) is not known to be compatible ...
# 16   No transcript definition for (tx_ac=NM_000371.4)
# 17        p.V142I: char 1: expected a letter or digit
# 18       c.424G>A: char 1: expected a letter or digit
# 19              TTR:g.29178618: char 15: end of input
# 20      NC_000018.9:g.29178618: char 23: end of input

# %%
result.to_csv('../data/results.csv', index=False)

# %%
import hgvs.validator
import hgvs.exceptions
vr = hgvs.validator.Validator(hdp=hdp)
try:
    vr.validate( hp.parse_hgvs_variant('NM_000371.4:c.220G>C') )
except hgvs.exceptions.HGVSError as e:
    print(e)
# Out:
# No transcript definition for (tx_ac=NM_000371.4)

# %%
hgvs_list = ['NC_000017.11:g.43091687delC', 'NC_000007.13.g.21726874G>A']

try:
    parser = hgvs.parser.Parser()
    validator = hgvs.validator.IntrinsicValidator()
    
    for hgvs in hgvs_list:
        variant = parser.parse_hgvs_variant(hgvs)
        validator.validate(variant)
except Exception as e:
    print(e)

import hgvs.validator
import hgvs.exceptions
vr = hgvs.validator.Validator(hdp=hdp)
try:
    vr.validate( hp.parse_hgvs_variant('NM_001267550.2(TTN):c.80006G>A') )
except hgvs.exceptions.HGVSError as e:
    print(e)


from hgvs.exceptions import HGVSError
import hgvs.parser
import hgvs.validator

hgvs_list = ('NC_000017.11:g.43091687delC', 'NC_000007.13.g.21726874G>A')

# Create a validator instance
vr = hgvs.validator.Validator(hdp=hdp)

# Create a parser instance
hp = hgvs.parser.Parser()

try:
    for hgvs in hgvs_list:
        vr.validate(hp.parse_hgvs_variant(hgvs))
        print('expression passed: {}'.format(hgvs))
except HGVSError as e:
    print(e)
